# %%
import scipy.io as scio
import matplotlib.pyplot as plt
import numpy as np

data_nore = scio.loadmat(r'changingNores\TestAccuracy_ChangingSpeed_Train96.187Test94.068.mat')
data_nore = data_nore['test_acc']
length = range(len(data_nore))
plt.plot(length,data_nore)
plt.show()

# %%
data_ms = scio.loadmat(r'changingMS\TestAccuracy_ChangingSpeed_Train97.126Test94.300.mat')
data_ms = data_ms['test_acc']
length = range(len(data_ms))
plt.plot(length,data_ms)
plt.show()

# %%
data_3 = scio.loadmat(r'changing3x3\TestAccuracy_ChangingSpeed_Train98.424Test93.188.mat')
data_3 = data_3['test_acc']
length = range(len(data_3))
plt.plot(length,data_3)
plt.show()

# %%
data_5 = scio.loadmat(r'changing5x5\TestAccuracy_ChangingSpeed_Train96.628Test93.466.mat')
data_5= data_5['test_acc']
length = range(len(data_5))
plt.plot(length,data_5)
plt.show()

# %%
data_7 = scio.loadmat(r'changing7x7\TestAccuracy_ChangingSpeed_Train97.601Test92.585.mat')
data_7= data_7['test_acc']
length = range(len(data_7))
plt.plot(length,data_7)
plt.show()
